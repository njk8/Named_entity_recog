# %%
import os
import re
import json
import pandas as pd

# Paths
EXTRACTED_DATA_FILE = "../data/processed/extracted_data.json"
CLEANED_DATA_FILE = "../data/processed/cleaned_data.csv"

# Define regex patterns for extracting PO fields
PO_NUMBER_PATTERN = r"(PO-PO-\d+)"  # Pattern to extract PO number from content
DELIVERY_DATE_PATTERN = r"(?i)Delivery by\s+([A-Za-z]+\s+\d{1,2},\s+\d{4})"  # Pattern to capture delivery date
PRODUCT_PATTERN = r"(\d+\s*\d+\s*units\s*of\s*([^\(]+)\s*\()"  # Pattern to capture product and units
ITEM_CODE_PATTERN = r"\(Item Code:\s*([^)]+)\)"  # Pattern to capture Item Code

# Keywords to capture in the Notes column
NOTES_KEYWORDS = ["urgent", "ASAP", "confirm availability"]

def clean_text(text):
    """Clean extracted text: remove extra spaces, special characters, and normalize text."""
    text = text.replace("\n", " ").strip()
    text = re.sub(r'\s+', ' ', text)  # Remove multiple spaces
    return text

def extract_notes(text):
    """Extract notes based on specific keywords."""
    notes = []
    for keyword in NOTES_KEYWORDS:
        if re.search(rf"\b{keyword}\b", text, re.IGNORECASE):  # Case-insensitive search
            notes.append(keyword)
    return ", ".join(notes) if notes else None  # Join keywords into a single string

def extract_fields(text):
    """Extract key fields from text using regex."""
    po_number = re.search(PO_NUMBER_PATTERN, text)
    delivery_date = re.search(DELIVERY_DATE_PATTERN, text)

    # Extract product, units, and item codes
    product_matches = re.findall(PRODUCT_PATTERN, text)  # Extract product and units
    item_codes = re.findall(ITEM_CODE_PATTERN, text)  # Extract item codes

    # Combine product, units, and item codes into a list of dictionaries
    items = []
    for i, (unit_product, product) in enumerate(product_matches):
        if i < len(item_codes):  # Ensure there's a corresponding item code
            unit = re.search(r"\d+", unit_product).group()  # Extract units from the match
            items.append({
                "Product": product.strip(),
                "Units": unit,
                "Item Code": item_codes[i]
            })

    # Extract notes
    notes = extract_notes(text)

    return {
        "PO Number": po_number.group(1) if po_number else None,
        "Delivery Date": delivery_date.group(1) if delivery_date else None,
        "Items": items,  # List of dictionaries containing product, units, and item code
        "Notes": notes  # Add extracted notes
    }

dff = pd.DataFrame()
def clean_and_structure_data():
    """Load extracted data, clean and structure it, and save to CSV."""
    if not os.path.exists(EXTRACTED_DATA_FILE):
        print(f"Error: {EXTRACTED_DATA_FILE} not found!")
        return

    with open(EXTRACTED_DATA_FILE, "r", encoding="utf-8") as f:
        raw_data = json.load(f)

    structured_data = []
    for entry in raw_data:
        filename = entry["filename"]
        content = clean_text(entry["content"])
        extracted_fields = extract_fields(content)

        # Extract PO number from filename (e.g., "PO_123_ClientName.txt" -> "PO_123")
        po_from_filename = re.search(r"PO_\d+", filename)
        po_number = po_from_filename.group(0) if po_from_filename else None

        # Extract client name from filename (e.g., "PO_123_ClientName.txt" -> "ClientName")
        client_name = re.sub(r"\.\w+$", "", filename)    # Remove .txt extension
        client_name = re.sub(r"_PO_\d+$", "", client_name)  # Remove "_PO_<digits>" suffix

        # Add extracted fields to the result
        extracted_fields["PO Number"] = po_number  # Override PO number from filename
        extracted_fields["Client Name"] = client_name
        structured_data.append(extracted_fields)

    # Convert structured data to a DataFrame for CSV output
    df = pd.DataFrame(structured_data)

    # Normalize item details for better CSV formatting
    df_items = df.explode("Items")  # Explode the list of items into separate rows
    df_items = pd.concat([df_items.drop(columns=["Items"]), df_items["Items"].apply(pd.Series)], axis=1)
    dff = df_items
    print(df_items.to_string())


    # Save the cleaned data to a CSV file
    #df_items.to_csv(CLEANED_DATA_FILE, index=False)

clean_and_structure_data()
# Out:
#    PO Number      Delivery Date                 Notes           Client Name             Product Units Item Code
# 0      PO_12  February 09, 2025                  None      Allen_Consulting  Pneumatic Cylinder   197   MA-2200
# 0      PO_12  February 09, 2025                  None      Allen_Consulting     Compressor Unit   322   MA-2200
# 0      PO_12  February 09, 2025                  None      Allen_Consulting      Hydraulic Pump   298   CU-5643
# 1      PO_27  February 03, 2025                  None      Allen_Consulting      Hydraulic Pump   321   MA-2200
# 2      PO_09  February 20, 2025                  None   Anderson_Industries  Pneumatic Cylinder   270   PC-1122
# 2      PO_09  February 20, 2025                  None   Anderson_Industries        Gear Reducer   446   MA-2200
# 3      PO_22               None                urgent   Anderson_Industries        Gear Reducer    73   CB-3300
# 4      PO_52   January 29, 2025                  None   Anderson_Industries       Control Valve    53   HP-1001
# 4      PO_52   January 29, 2025                  None   Anderson_Industries    Electrical Panel   359   MA-2200
# 4      PO_52   January 29, 2025                  None   Anderson_Industries      Heat Exchanger   439   GR-4500
# 5      PO_11               None                  ASAP             Brown_Inc      Heat Exchanger   299   CV-6677
# 5      PO_11               None                  ASAP             Brown_Inc      Heat Exchanger   167   PC-1122
# 5      PO_11               None                  ASAP             Brown_Inc      Motor Assembly   230   HP-1001
# 6      PO_13               None                  ASAP             Brown_Inc      Heat Exchanger   299   CV-6677
# 6      PO_13               None                  ASAP             Brown_Inc      Heat Exchanger   167   PC-1122
# 6      PO_13               None                  ASAP             Brown_Inc      Motor Assembly   230   HP-1001
# 7      PO_50               None                  None             Brown_Inc      Motor Assembly   264   CV-6677
# 8      PO_55               None                  None             Brown_Inc         Bearing Set   355   EP-9012
# 9      PO_58  February 12, 2025                  None             Brown_Inc         Bearing Set   135   CV-6677
# 9      PO_58  February 12, 2025                  None             Brown_Inc         Bearing Set   304   HE-2345
# 10     PO_30               None                  None            Clark_Tech    Electrical Panel   368   EP-9012
# 10     PO_30               None                  None            Clark_Tech      Heat Exchanger   119   EP-9012
# 11     PO_07               None                  ASAP       Garcia_Services      Motor Assembly   181   HE-2345
# 11     PO_07               None                  ASAP       Garcia_Services      Motor Assembly   273   MA-2200
# 12     PO_56               None                  ASAP       Garcia_Services      Motor Assembly   181   HE-2345
# 12     PO_56               None                  ASAP       Garcia_Services      Motor Assembly   273   MA-2200
# 13     PO_26               None                  None        Harris_Company      Motor Assembly   194   PC-1122
# 13     PO_26               None                  None        Harris_Company       Control Valve   186   CB-3300
# 14     PO_46  February 20, 2025                  None        Harris_Company        Gear Reducer   307   CU-5643
# 15     PO_47  February 20, 2025                  None        Harris_Company    Electrical Panel   248   CU-5643
# 15     PO_47  February 20, 2025                  None        Harris_Company      Heat Exchanger   102   HE-2345
# 15     PO_47  February 20, 2025                  None        Harris_Company       Conveyor Belt    73   CU-5643
# 16     PO_08               None                  None          Hernandez_Co         Bearing Set   498   CV-6677
# 17     PO_32               None                urgent          Hernandez_Co         Bearing Set   402   CU-5643
# 17     PO_32               None                urgent          Hernandez_Co      Heat Exchanger   330   BS-7890
# 18     PO_06               None                  None        Lewis_Supplies     Compressor Unit   375   PC-1122
# 18     PO_06               None                  None        Lewis_Supplies    Electrical Panel   319   MA-2200
# 18     PO_06               None                  None        Lewis_Supplies      Hydraulic Pump   234   CB-3300
# 19     PO_17  February 03, 2025                  None        Lewis_Supplies       Conveyor Belt   137   PC-1122
# 19     PO_17  February 03, 2025                  None        Lewis_Supplies     Compressor Unit   189   HE-2345
# 19     PO_17  February 03, 2025                  None        Lewis_Supplies         Bearing Set    42   BS-7890
# 20     PO_18               None  confirm availability        Lewis_Supplies        Gear Reducer   440   HP-1001
# 21     PO_38               None                  ASAP        Lewis_Supplies      Motor Assembly   311   EP-9012
# 21     PO_38               None                  ASAP        Lewis_Supplies       Control Valve   356   CU-5643
# 21     PO_38               None                  ASAP        Lewis_Supplies    Electrical Panel   143   CV-6677
# 22     PO_01  February 18, 2025                  None          Martinez_LLC      Hydraulic Pump   272   GR-4500
# 23     PO_19               None  confirm availability          Martinez_LLC        Gear Reducer   322   CV-6677
# 23     PO_19               None  confirm availability          Martinez_LLC  Pneumatic Cylinder   391   HE-2345
# 23     PO_19               None  confirm availability          Martinez_LLC    Electrical Panel   168   HP-1001
# 24     PO_29               None                urgent          Martinez_LLC       Conveyor Belt   375   GR-4500
# 25     PO_33               None                urgent          Martinez_LLC       Conveyor Belt   375   GR-4500
# 26     PO_54               None                urgent          Martinez_LLC       Control Valve   385   CV-6677
# 26     PO_54               None                urgent          Martinez_LLC        Gear Reducer    49   EP-9012
# 26     PO_54               None                urgent          Martinez_LLC       Conveyor Belt   307   HP-1001
# 27     PO_04               None                  ASAP      Martin_Solutions     Compressor Unit   470   EP-9012
# 27     PO_04               None                  ASAP      Martin_Solutions      Hydraulic Pump   282   CU-5643
# 28     PO_34   January 26, 2025                  None      Martin_Solutions     Compressor Unit   319   CV-6677
# 29     PO_42   January 26, 2025                  None      Martin_Solutions     Compressor Unit   319   CV-6677
# 30     PO_53               None  confirm availability      Martin_Solutions       Control Valve   449   MA-2200
# 31     PO_21               None                  None  Robinson_Enterprises      Heat Exchanger   310   BS-7890
# 32     PO_23               None                  None  Robinson_Enterprises       Control Valve   198   MA-2200
# 32     PO_23               None                  None  Robinson_Enterprises         Bearing Set   104   HE-2345
# 32     PO_23               None                  None  Robinson_Enterprises        Gear Reducer   496   HP-1001
# 33     PO_02               None                  ASAP        Rodriguez_Corp  Pneumatic Cylinder    27   HP-1001
# 34     PO_60               None                  None        Rodriguez_Corp      Heat Exchanger   260   PC-1122
# 35     PO_05               None                urgent            Smith_Corp      Hydraulic Pump   135   GR-4500
# 35     PO_05               None                urgent            Smith_Corp      Heat Exchanger   135   PC-1122
# 35     PO_05               None                urgent            Smith_Corp       Conveyor Belt   155   BS-7890
# 36     PO_14  February 04, 2025                  None            Smith_Corp     Compressor Unit   397   HP-1001
# 37     PO_40   January 25, 2025                  None            Smith_Corp       Conveyor Belt   263   CU-5643
# 38     PO_49               None                urgent            Smith_Corp      Hydraulic Pump   135   GR-4500
# 38     PO_49               None                urgent            Smith_Corp      Heat Exchanger   135   PC-1122
# 38     PO_49               None                urgent            Smith_Corp       Conveyor Belt   155   BS-7890
# 39     PO_51  February 04, 2025                  None            Smith_Corp     Compressor Unit   397   HP-1001
# 40     PO_39   January 26, 2025                  None    Taylor_Enterprises      Heat Exchanger   127   HE-2345
# 40     PO_39   January 26, 2025                  None    Taylor_Enterprises     Compressor Unit    14   HE-2345
# 41     PO_41   January 26, 2025                  None    Taylor_Enterprises      Heat Exchanger   127   HE-2345
# 41     PO_41   January 26, 2025                  None    Taylor_Enterprises     Compressor Unit    14   HE-2345
# 42     PO_45               None                  None    Taylor_Enterprises     Compressor Unit   125   CV-6677
# 43     PO_48               None                urgent    Taylor_Enterprises      Motor Assembly   174   HE-2345
# 43     PO_48               None                urgent    Taylor_Enterprises      Heat Exchanger   146   CV-6677
# 44     PO_59               None                urgent    Taylor_Enterprises        Gear Reducer   229   CB-3300
# 44     PO_59               None                urgent    Taylor_Enterprises      Motor Assembly   205   MA-2200
# 44     PO_59               None                urgent    Taylor_Enterprises       Control Valve   124   GR-4500
# 45     PO_03               None                  None          Thomas_Group     Compressor Unit   375   PC-1122
# 45     PO_03               None                  None          Thomas_Group      Motor Assembly   123   EP-9012
# 45     PO_03               None                  None          Thomas_Group      Heat Exchanger   217   EP-9012
# 46     PO_15               None                  None          Thomas_Group         Bearing Set   243   CV-6677
# 46     PO_15               None                  None          Thomas_Group         Bearing Set   402   MA-2200
# 46     PO_15               None                  None          Thomas_Group      Hydraulic Pump   201   CU-5643
# 47     PO_16               None                urgent          Thomas_Group      Hydraulic Pump   169   PC-1122
# 48     PO_20               None                urgent          Thomas_Group      Motor Assembly   225   MA-2200
# 48     PO_20               None                urgent          Thomas_Group      Motor Assembly   390   PC-1122
# 49     PO_36               None                urgent          Thomas_Group         Bearing Set   313   CV-6677
# 50     PO_43               None                urgent   Thompson_Consulting     Compressor Unit   103   BS-7890
# 51     PO_10               None                urgent    Walker_Enterprises     Compressor Unit   417   CB-3300
# 51     PO_10               None                urgent    Walker_Enterprises      Heat Exchanger   278   CB-3300
# 51     PO_10               None                urgent    Walker_Enterprises    Electrical Panel   177   GR-4500
# 52     PO_24  February 17, 2025                  None    Walker_Enterprises       Control Valve    93   CB-3300
# 52     PO_24  February 17, 2025                  None    Walker_Enterprises    Electrical Panel   274   PC-1122
# 52     PO_24  February 17, 2025                  None    Walker_Enterprises       Control Valve   436   CB-3300
# 53     PO_25  February 17, 2025                  None    Walker_Enterprises       Control Valve    93   CB-3300
# 53     PO_25  February 17, 2025                  None    Walker_Enterprises    Electrical Panel   274   PC-1122
# 53     PO_25  February 17, 2025                  None    Walker_Enterprises       Control Valve   436   CB-3300
# 54     PO_28               None                  None           Young_Group       Conveyor Belt   344   HE-2345
# 55     PO_31               None                  None           Young_Group     Compressor Unit   235   PC-1122
# 56     PO_35               None                  None           Young_Group      Motor Assembly   298   HE-2345
# 56     PO_35               None                  None           Young_Group    Electrical Panel   409   CB-3300
# 57     PO_37  February 12, 2025                  None           Young_Group        Gear Reducer    30   CB-3300
# 57     PO_37  February 12, 2025                  None           Young_Group      Hydraulic Pump   419   MA-2200
# 57     PO_37  February 12, 2025                  None           Young_Group      Motor Assembly   484   BS-7890
# 58     PO_44  February 12, 2025                  None           Young_Group        Gear Reducer    30   CB-3300
# 58     PO_44  February 12, 2025                  None           Young_Group      Hydraulic Pump   419   MA-2200
# 58     PO_44  February 12, 2025                  None           Young_Group      Motor Assembly   484   BS-7890
# 59     PO_57               None                  None           Young_Group       Conveyor Belt   470   CU-5643
# 59     PO_57               None                  None           Young_Group      Motor Assembly   176   CU-5643

# %%
import re

filename = "PO_123_ClientName.txt"

# Remove file extension
client_name = re.sub(r"\.\w+$", "", filename)  

# Remove "PO_" followed by digits and an underscore
client_name = re.sub(r"^PO_\d+_", "", client_name)  

print(client_name)
# Out:
# ClientName

# %% [markdown]
# #using deployed AZURE NER API

# %%
# -------------------------------------------------------------------------
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License. See License.txt in the project root for
# license information.
# --------------------------------------------------------------------------

"""
FILE: sample_recognize_custom_entities.py

DESCRIPTION:
    This sample demonstrates how to recognize custom entities in documents.
    Recognizing custom entities is also available as an action type through the begin_analyze_actions API.

    For information on regional support of custom features and how to train a model to
    recognize custom entities, see https://aka.ms/azsdk/textanalytics/customentityrecognition

USAGE:
    python sample_recognize_custom_entities.py

    Set the environment variables with your own values before running the sample:
    1) AZURE_LANGUAGE_ENDPOINT - the endpoint to your Language resource.
    2) AZURE_LANGUAGE_KEY - your Language subscription key
    3) CUSTOM_ENTITIES_PROJECT_NAME - your Language Studio project name
    4) CUSTOM_ENTITIES_DEPLOYMENT_NAME - your Language Studio deployment name
"""


def sample_recognize_custom_entities() -> None:
    # [START recognize_custom_entities]
    import os
    from azure.core.credentials import AzureKeyCredential
    from azure.ai.textanalytics import TextAnalyticsClient

    RAW_DATA_DIR = "../data/raw/Thomas_Group_PO_16.txt"
    endpoint = os.environ[YOUR_ENDPOINT_VALUE]
    key = os.environ[YOUR_KEY_VALUE]
    project_name = os.environ[YOUR_PROJECT_NAME]
    deployment_name = os.environ[YOUR_DEPLOYMENT_NAME]
    path_to_sample_document = os.path.join(RAW_DATA_DIR)

    text_analytics_client = TextAnalyticsClient(
        endpoint=endpoint,
        credential=AzureKeyCredential(key),
    )

    with open(path_to_sample_document) as fd:
        document = [fd.read()]

    poller = text_analytics_client.begin_recognize_custom_entities(
        document,
        project_name=project_name,
        deployment_name=deployment_name
    )

    document_results = poller.result()
    for custom_entities_result in document_results:
        if custom_entities_result.kind == "CustomEntityRecognition":
            for entity in custom_entities_result.entities:
                print(
                    "Entity '{}' has category '{}' with confidence score of '{}'".format(
                        entity.text, entity.category, entity.confidence_score
                    )
                )
        elif custom_entities_result.is_error is True:
            print("...Is an error with code '{}' and message '{}'".format(
                custom_entities_result.error.code, custom_entities_result.error.message
                )
            )
    # [END recognize_custom_entities]


if __name__ == "__main__":
    sample_recognize_custom_entities()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 73
#      69     # [END recognize_custom_entities]
#      72 if __name__ == "__main__":
# ---> 73     sample_recognize_custom_entities()
#
# Cell In[6], line 32, in sample_recognize_custom_entities()
#      30 import os
#      31 from azure.core.credentials import AzureKeyCredential
# ---> 32 from azure.ai.textanalytics import TextAnalyticsClient
#      34 RAW_DATA_DIR = "../data/raw/Thomas_Group_PO_16.txt"
#      35 endpoint = os.environ["https://norraus.cognitiveservices.azure.com/"]
#
# File c:\Users\91940\anaconda3\envs\novac\lib\site-packages\azure\ai\textanalytics\__init__.py:6
#       1 # ------------------------------------
#       2 # Copyright (c) Microsoft Corporation.
#       3 # Licensed under the MIT License.
#       4 # ------------------------------------
# ----> 6 from ._text_analytics_client import TextAnalyticsClient
#       7 from ._version import VERSION
#       8 from ._base_client import TextAnalyticsApiVersion
#
# File c:\Users\91940\anaconda3\envs\novac\lib\site-packages\azure\ai\textanalytics\_text_analytics_client.py:21
#      19 from ._base_client import TextAnalyticsClientBase
#      20 from ._lro import AnalyzeActionsLROPoller, AnalyzeHealthcareEntitiesLROPoller
# ---> 21 from ._request_handlers import (
#      22     _validate_input,
#      23     _determine_action_type,
#      24 )
#      25 from ._validate import validate_multiapi_args, check_for_unsupported_actions_types
#      26 from ._version import DEFAULT_API_VERSION
#
# File c:\Users\91940\anaconda3\envs\novac\lib\site-packages\azure\ai\textanalytics\_base_client.py:12
#      10 from azure.core.credentials import AzureKeyCredential
#      11 from ._generated import TextAnalyticsClient as _TextAnalyticsClient
# ---> 12 from ._policies import TextAnalyticsResponseHookPolicy
#      13 from ._user_agent import USER_AGENT
#      14 from ._version import DEFAULT_API_VERSION
#
# File c:\Users\91940\anaconda3\envs\novac\lib\site-packages\azure\ai\textanalytics\_policies.py:9
#       7 from azure.core.pipeline.policies import SansIOHTTPPolicy
#       8 from ._models import TextDocumentBatchStatistics
# ----> 9 from ._lro import _FINISHED
#      12 class TextAnalyticsResponseHookPolicy(SansIOHTTPPolicy):
#      13     def __init__(self, **kwargs):
#
# File c:\Users\91940\anaconda3\envs\novac\lib\site-packages\azure\ai\textanalytics\_models.py:12
#       7 from enum import Enum
#       8 from azure.core import CaseInsensitiveEnumMeta
#       9 from ._generated.models import (
#      10     LanguageInput,
#      11     MultiLanguageInput,
# ---> 12 )
#      13 from ._generated.v3_0 import models as _v3_0_models
#      14 from ._generated.v3_1 import models as _v3_1_models
#
# ImportError: cannot import name 'PiiEntityCategory' from 'azure.ai.textanalytics._generated.models' (c:\Users\91940\anaconda3\envs\novac\lib\site-packages\azure\ai\textanalytics\_generated\models.py)
